# %%
from selenium import webdriver
import time 

driver=webdriver.Chrome()  #C is in uppercase
# driver is variable

driver.get('https://www.flipkart.com/')
time.sleep(5)

driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time 

driver=webdriver.Chrome()  #C is in uppercase
# driver is variable

driver.get('https://www.flipkart.com/')
time.sleep(3)

driver.find_element(By.CLASS_NAME,"b3wTlE",).click  # bcs it is a button
time.sleep(3)

driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time 

driver=webdriver.Chrome()  #C is in uppercase
# driver is variable

driver.get('https://www.flipkart.com/')
time.sleep(3)

driver.find_element(By.CLASS_NAME,"b3wTlE").click()  # bcs it is a button
time.sleep(3)

search_box=driver.find_element(By.NAME,"q")
search_box.send_keys('laptops')
search_box.send_keys(Keys.ENTER)
time.sleep(3)


image=driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[2]/div/div/div/a/div[1]/div[1]/div[1]/div/img')

image.screenshot('laptop_img.jpg')

#driver.screenshot('webpage.jpg')
driver.quit()
# Out:
# c:\Users\ANJANA\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webelement.py:451: UserWarning: name used for saved screenshot does not match file type. It should end with a `.png` extension
#   warnings.warn(

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time 

driver=webdriver.Chrome()  #C is in uppercase
# driver is variable

driver.get('https://www.flipkart.com/')
time.sleep(3)

driver.find_element(By.CLASS_NAME,"b3wTlE").click()  # bcs it is a button
time.sleep(3)

search_box=driver.find_element(By.NAME,"q")
search_box.send_keys('laptops')
search_box.send_keys(Keys.ENTER)
time.sleep(3)

name=driver.find_element(By.CLASS_NAME,'UCc1lI').text      #name of laptop
print(name)
price=driver.find_element(By.CSS_SELECTOR,'.hZ3P6w.DeU9vF').text        #price of laptop
print(price)

time.sleep(2)
#driver.screenshot('webpage.jpg')
driver.quit()
# Out:
# ₹17,990

# %% [markdown]
# # day2

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time 

driver=webdriver.Chrome()  #C is in uppercase
# driver is variable

driver.get('https://www.flipkart.com/')
time.sleep(3)

driver.find_element(By.CLASS_NAME,"b3wTlE").click()  # bcs it is a button
time.sleep(3)

search_box=driver.find_element(By.NAME,"q")  # input tag
search_box.send_keys('samsung mobiles')
search_box.send_keys(Keys.ENTER)
time.sleep(3)

div_lst=driver.find_elements(By.CLASS_NAME,'jIjQ8S')
names,prices=[],[]
for d in div_lst:
    try:
        price = d.find_element(By.CSS_SELECTOR, '.hZ3P6w.DeU9vF').text
    except:
        price = "Not Available"
    prices.append(price)

time.sleep(2)
driver.quit()

# %%
len(names)
# Out:
# 0

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time 

driver=webdriver.Chrome()  #C is in uppercase
# driver is variable
driver=webdriver.Chrome()
driver.maximize_window()
driver.get('https://www.flipkart.com/')
time.sleep(3)

driver.find_element(By.CLASS_NAME,"b3wTlE").click()  # bcs it is a button
time.sleep(3)

search_box=driver.find_element(By.NAME,"q")  # input tag
search_box.send_keys('samsung mobiles')
search_box.send_keys(Keys.ENTER)
time.sleep(3)

div_lst=driver.find_elements(By.CLASS_NAME,'jIjQ8S')
names,prices=[],[]
for d in div_lst:
    try:
        names.append(d.find_element(By.CLASS_NAME,'RG5Slk').text)
    except:
        names.append('unknown')
    try:
        prices.append(d.find_element(By.CSS_SELECTOR,'.hZ3P6w.DeU9vF').text)
    except:
        prices.append(None)

time.sleep(2)
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time 
import pandas as pd

driver=webdriver.Chrome()  #C is in uppercase
# driver is variable
driver=webdriver.Chrome()
driver.maximize_window()
driver.get('https://www.flipkart.com/')
time.sleep(3)

driver.find_element(By.CLASS_NAME,"b3wTlE").click()  # bcs it is a button
time.sleep(3)

search_box=driver.find_element(By.NAME,"q")  # input tag
search_box.send_keys('samsung mobiles')
search_box.send_keys(Keys.ENTER)
time.sleep(3)

names,prices=[],[]

for i in range(1,11):

    div_lst=driver.find_elements(By.CLASS_NAME,'jIjQ8S')

    for d in div_lst:
        try:
            names.append(d.find_element(By.CLASS_NAME,'RG5Slk').text)
        except:
            names.append('unknown')
        try:
            prices.append(d.find_element(By.CSS_SELECTOR,'.hZ3P6w.DeU9vF').text)
        except:
            prices.append(None)

    driver.find_elements(By.CLASS_NAME,'jgg0SZ')[-1].click()
    time.sleep(4)

time.sleep(2)
driver.quit()

# %%
d={'names':names, 'prices':prices}
df=pd.DataFrame(d)
df.to_excel('samsung_mobiles.xlsx')
